# %% [markdown]
# # **Jenga School Project**

# %% [markdown]
# Goal:
#
#
# 1.   Identify relationship between power generation and country development across the world
# 2.   Identify if the amount of power usage/generation has direct impact on a country's development.
#
# - This is to be analyzed in conjunction with the different sources of energy, energy consumption per acipta across the world as well as CO2 emissions.
# - This should should show the role played by energy in the world development indicator.
# **The sample size is selected from continent regions with the highest GDP per capita in 2017.(Three countries per region)
#
# **Sample Size**
#
# The sample size of the countries used are from:
#
# **Africa**
#
# 1.   Central Africa: Angola and Congo
# 2.   Eastern Africa: Seychelles and Mauritius
# 3.   Western Africa: Nigeria and Ghana
# 4.   Southern Africa : South Africa and Botswana
# 5.   Northern Africa : Tunisia and Algeria
# **Europe**
#
# 1.   Eastern Europe : Czech Republic and Slovakia
# 2.   Western Europe :Luxembourg and Switzerland
# 4.   Northern Europe: Ireland and Norway
# 5.   Southern Europe: San Marino and Italy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
df= pd.read_csv('/Users/bobbynjorogekimani/Desktop/Github/Power/files/per-capita-energy-use_countries.csv',encoding= 'unicode_escape')

continents= pd.read_csv('/Users/bobbynjorogekimani/Desktop/Github/Power/files/per-capita-energy-use_continents.csv',encoding= 'unicode_escape')

# %%
print(continents)
# Out:
#          ï»¿Entity  Code  Year  Energy consumption per capita (kWh)
# 0           Africa   NaN  1965                          2178.897737
# 1           Africa   NaN  1966                          2234.789825
# 2           Africa   NaN  1967                          2197.197691
# 3           Africa   NaN  1968                          2259.624226
# 4           Africa   NaN  1969                          2255.869649
# ..             ...   ...   ...                                  ...
# 160  North America   NaN  2015                         88562.993840
# 161  North America   NaN  2016                         87878.288500
# 162  North America   NaN  2017                         87748.431540
# 163  North America   NaN  2018                         89812.396930
# 164  North America   NaN  2019                         88336.805100
#
# [165 rows x 4 columns]

# %%
df['ï»¿country'].value_counts()
# Out:
# Saudi Arabia    55
# Slovakia        55
# Italy           55
# Oman            55
# Japan           55
#                 ..
# Eritrea         23
# Palestine       20
# Timor           14
# Montenegro      11
# South Sudan      5
# Name: ï»¿country, Length: 212, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['ï»¿country', 'code', 'year', 'energy_consumption_per_capita'], dtype='object')

# %%
print(continents.columns)
# Out:
# Index(['ï»¿Entity', 'Code', 'Year', 'Energy consumption per capita (kWh)'], dtype='object')

# %%
df[(['energy_consumption_per_capita'])][:20].plot(kind='bar');#

# %%
# fig, ax = plt.subplots(figsize=(15, 5))
# plt.title("Afghanistan",fontsize=10)
# plt.ylabel("Years",fontsize=10)
# df.plot(kind="bar",ax=ax,fontsize=10)#groups by route and seat state(gender)
# plt.xlabel("Energy",fontsize=10)
# plt.show()

# %%
#create a data frame for all the countries in the sample size
#afghanistan = df[(df['ï»¿country'] == 'Afghanistan') & (df['code'] == 'AFG')] #code to create a single data frame for a country
#df = pd.DataFrame
angola = df[(df['ï»¿country'] == 'Angola') & (df['code'] == 'AGO')]
# df[(df['ï»¿country'] == 'Congo') & (df['code'] == 'COG')],
# df[(df['ï»¿country'] == 'Seychelles') & (df['code'] == 'SYC')],
# df[(df['ï»¿country'] == 'Mauritius') & (df['code'] == 'MUS')],
# df[(df['ï»¿country'] == 'Nigeria') & (df['code'] == 'NGA')],
# df[(df['ï»¿country'] == 'Ghana') & (df['code'] == 'GHA')],
# df[(df['ï»¿country'] == 'South Africa') & (df['code'] == 'ZAF')],
# df[(df['ï»¿country'] == 'Botswana') & (df['code'] == 'BWA')],
# df[(df['ï»¿country'] == 'Tunisia') & (df['code'] == 'TUN')],
# df[(df['ï»¿country'] == 'Algeria') & (df['code'] == 'DZA')],
# df[(df['ï»¿country'] == 'Czech Republic') & (df['code'] == 'CZE')],
# df[(df['ï»¿country'] == 'Slovakia') & (df['code'] == 'SVK')],
# df[(df['ï»¿country'] == 'Luxembourg') & (df['code'] == 'LUX')],
# df[(df['ï»¿country'] == 'Switzerland') & (df['code'] == 'CHE')],
# df[(df['ï»¿country'] == 'Ireland') & (df['code'] == 'IRL')],
# df[(df['ï»¿country'] == 'Norway') & (df['code'] == 'NOR')],
# df[(df['ï»¿country'] == 'Italy') & (df['code'] == 'ITA')],
# df[(df['ï»¿country'] == 'Malta') & (df['code'] == 'MLT')])


# seychelles = df[(df['ï»¿country'] == 'Seychelles') & (df['code'] == 'SYC')]
# mauritius = df[(df['ï»¿country'] == 'Mauritius') & (df['code'] == 'MUS')]
# nigeria = df[(df['ï»¿country'] == 'Nigeria') & (df['code'] == 'NGA')]
# ghana = df[(df['ï»¿country'] == 'Ghana') & (df['code'] == 'GHA')]
# sa = df[(df['ï»¿country'] == 'South Africa') & (df['code'] == 'ZAF')]
# botswana = df[(df['ï»¿country'] == 'Botswana') & (df['code'] == 'BWA')]
# tunisia = df[(df['ï»¿country'] == 'Tunisia') & (df['code'] == 'TUN')]
# algeria = df[(df['ï»¿country'] == 'Algeria') & (df['code'] == 'DZA')]
# czech = df[(df['ï»¿country'] == 'Czech Republic') & (df['code'] == 'CZE')]
# slovakia = df[(df['ï»¿country'] == 'Slovakia') & (df['code'] == 'SVK')]
# luxembourg = df[(df['ï»¿country'] == 'Luxembourg') & (df['code'] == 'LUX')]
# switzerland = df[(df['ï»¿country'] == 'Switzerland') & (df['code'] == 'CHE')]
# ireland = df[(df['ï»¿country'] == 'Ireland') & (df['code'] == 'IRL')]
# norway = df[(df['ï»¿country'] == 'Norway') & (df['code'] == 'NOR')]
# italy = df[(df['ï»¿country'] == 'Italy') & (df['code'] == 'ITA')]
# malta = df[(df['ï»¿country'] == 'Malta') & (df['code'] == 'MLT')]

# %%
#creating independent dataframes for all the countries
congo= pd.DataFrame(df[(df['ï»¿country'] == 'Congo') & (df['code'] == 'COG')])
angola= pd.DataFrame(df[(df['ï»¿country'] == 'Angola') & (df['code'] == 'AGO')])
seychelles= pd.DataFrame(df[(df['ï»¿country'] == 'Seychelles') & (df['code'] == 'SYC')])
mauritius= pd.DataFrame(df[(df['ï»¿country'] == 'Mauritius') & (df['code'] == 'MUS')])
nigeria= pd.DataFrame(df[(df['ï»¿country'] == 'Nigeria') & (df['code'] == 'NGA')])
ghana= pd.DataFrame(df[(df['ï»¿country'] == 'Ghana') & (df['code'] == 'GHA')])
sa= pd.DataFrame(df[(df['ï»¿country'] == 'South Africa') & (df['code'] == 'ZAF')])
botswana= pd.DataFrame(df[(df['ï»¿country'] == 'Botswana') & (df['code'] == 'BWA')])
tunisia= pd.DataFrame(df[(df['ï»¿country'] == 'Tunisia') & (df['code'] == 'TUN')])
algeria= pd.DataFrame(df[(df['ï»¿country'] == 'Algeria') & (df['code'] == 'DZA')])
czech= pd.DataFrame(df[(df['ï»¿country'] == 'Czech Republic') & (df['code'] == 'CZE')])
slovakia= pd.DataFrame(df[(df['ï»¿country'] == 'Slovakia') & (df['code'] == 'SVK')])
luxembourg= pd.DataFrame(df[(df['ï»¿country'] == 'Luxembourg') & (df['code'] == 'LUX')])
switzerland= pd.DataFrame(df[(df['ï»¿country'] == 'Switzerland') & (df['code'] == 'CHE')])
ireland= pd.DataFrame(df[(df['ï»¿country'] == 'Ireland') & (df['code'] == 'IRL')])
norway= pd.DataFrame(df[(df['ï»¿country'] == 'Norway') & (df['code'] == 'NOR')])
italy= pd.DataFrame(df[(df['ï»¿country'] == 'Italy') & (df['code'] == 'ITA')])
malta= pd.DataFrame(df[(df['ï»¿country'] == 'Malta') & (df['code'] == 'MLT')])

# %% [markdown]
# # Combine Country Dataframes Based On The Regions For Easier Analysis

# %%
central_africa = angola.append([congo])

east_africa = seychelles.append([mauritius])

west_africa = ghana.append([nigeria])

southern_africa = sa.append([botswana])

northern_africa = tunisia.append([algeria])

eastern_europe = czech.append([slovakia])

western_europe = switzerland.append([luxembourg])

northern_europe = ireland.append([norway])

southern_europe = italy.append([malta])

# %% [markdown]
# Further cleaning of the Dataframes to remove unwanted columns('Code')

# %%
#central_africa = central_africa.drop("code", axis=1)

east_africa = east_africa.drop("code", axis=1)


west_africa = west_africa.drop("code", axis=1)


southern_africa = southern_africa.drop("code", axis=1)


northern_africa = northern_africa.drop("code", axis=1)


eastern_europe =  eastern_europe.drop("code", axis=1)


western_europe = western_europe.drop("code", axis=1)


northern_europe = northern_europe.drop("code", axis=1)

southern_europe = southern_europe.drop("code", axis=1)

# %%
print(west_africa)
# Out:
#      ï»¿country  year  energy_consumption_per_capita
# 2912      Ghana  1980                    2238.984005
# 2913      Ghana  1981                    2094.342432
# 2914      Ghana  1982                    2037.943306
# 2915      Ghana  1983                    1312.307803
# 2916      Ghana  1984                    1194.576997
# ...         ...   ...                            ...
# 5581    Nigeria  2012                    2104.126160
# 5582    Nigeria  2013                    2136.410817
# 5583    Nigeria  2014                    2350.436879
# 5584    Nigeria  2015                    2342.666751
# 5585    Nigeria  2016                    2725.677548
#
# [74 rows x 3 columns]

# %% [markdown]
# # Plotting Energy Consumption For Countries In West Africa

# %%
#Plotting energy consumption for countries in West Africa
ghana.reset_index().plot(x='year',y='energy_consumption_per_capita',kind ='bar',stacked=False,width=0.9)
plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
plt.title('Energy Consumption per capita for Ghana')


nigeria.reset_index().plot(x='year',y='energy_consumption_per_capita',kind ='bar',stacked=False,width=0.9)
plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
plt.title('Energy Consumption per capita for Nigeria')


#plt.tight_layout(4)

plt.show()

# %%
# x = np.linspace(0, 2 * np.pi, 400)
# y = np.sin(x ** 2)


# ghana.reset_index().plt.subplots(x='year',y='energy_consumption_per_capita',kind ='bar',stacked=False,width=0.9)
# plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
# plt.title('Energy Consumption per capita for Ghana')

ghana.reset_index().plot(plt.subplots('year','energy_consumption_per_capita'))
plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
plt.title('Energy Consumption per capita for Ghana')



# fig, (ax1, ax2) = plt.subplots(1, 2)
# fig.suptitle('Horizontally stacked subplots')
# ax1.plot(x, y)
# ax2.plot(x, -y)

# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/hn/_s7l0yhj63n1q4zt7kts8sl40000gn/T/ipykernel_1732/355501829.py in <module>
#       7 # plt.title('Energy Consumption per capita for Ghana')
#       8
# ----> 9 ghana.reset_index().plot(plt.subplots('year','energy_consumption_per_capita'))
#      10 plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
#      11 plt.title('Energy Consumption per capita for Ghana')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# ...

# %% [markdown]
# # Plotting Energy Consumption For Countries in Central Africa

# %%
#Plotting energy consumption for countries in Central Africa

angola.reset_index().plot(x='year',y='energy_consumption_per_capita',kind ='bar',stacked=False,width=0.9)
plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
plt.title('Energy Consumption per capita for Angola')


congo.reset_index().plot(x='year',y='energy_consumption_per_capita',kind ='bar',stacked=False,width=0.9)
plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
plt.title('Energy Consumption per capita for Congo')
plt.show()

# %%
#Plotting energy consumption for countries in East Africa

seychelles.reset_index().plot(x='year',y='energy_consumption_per_capita',kind ='bar',stacked=False,width=0.9)
plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
plt.title('Energy Consumption per capita for Seychelles')


mauritius.reset_index().plot(x='year',y='energy_consumption_per_capita',kind ='bar',stacked=False,width=0.9)
plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
plt.title('Energy Consumption per capita for Mauritius')
plt.show()

# %%
#Plotting energy consumption for countries in Southern Africa

sa.reset_index().plot(x='year',y='energy_consumption_per_capita',kind ='bar',stacked=False,width=0.9)
plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
plt.title('Energy Consumption per capita for South Africa')


botswana.reset_index().plot(x='year',y='energy_consumption_per_capita',kind ='bar',stacked=False,width=0.9)
plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
plt.title('Energy Consumption per capita for Botswana')
plt.show()

# %%
#Plotting energy consumption for countries in Northern Africa

tunisia.reset_index().plot(x='year',y='energy_consumption_per_capita',kind ='bar',stacked=False,width=0.9)
plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
plt.title('Energy Consumption per capita for Tunisia')


algeria.reset_index().plot(x='year',y='energy_consumption_per_capita',kind ='bar',stacked=False,width=0.9)
plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
plt.title('Energy Consumption per capita for Algeria')
plt.show()

# %%
#Plotting energy consumption for countries in Eastern Europe
czech.reset_index().plot(x='year',y='energy_consumption_per_capita',kind ='bar',stacked=False,width=0.9)
plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
plt.title('Energy Consumption per capita for Czech Republic')


slovakia.reset_index().plot(x='year',y='energy_consumption_per_capita',kind ='bar',stacked=False,width=0.9)
plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
plt.title('Energy Consumption per capita for Slovakia')
plt.show()

# %% [markdown]
# # PLOTTING ENERGY CONSUMPTION FOR EUROPE

# %%
#Plotting energy consumption for countries in Western Europe
luxembourg.reset_index().plot(x='year',y='energy_consumption_per_capita',kind ='bar',stacked=False,width=0.9)
plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
plt.title('Energy Consumption per capita for Luxembourg')


switzerland.reset_index().plot(x='year',y='energy_consumption_per_capita',kind ='bar',stacked=False,width=0.9)
plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
plt.title('Energy Consumption per capita for Switzerland')
plt.show()

# %%
#Plotting energy consumption for countries in Northern Europe 
ireland.reset_index().plot(x='year',y='energy_consumption_per_capita',kind ='bar',stacked=False,width=0.9)
plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
plt.title('Energy Consumption per capita for Ireland')


norway.reset_index().plot(x='year',y='energy_consumption_per_capita',kind ='bar',stacked=False,width=0.9)
plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
plt.title('Energy Consumption per capita for Norway')
plt.show()

# %%
#Plotting energy consumption for countries in Southern Europe
italy.reset_index().plot(x='year',y='energy_consumption_per_capita',kind ='bar',stacked=False,width=0.9)
plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
plt.title('Energy Consumption per capita for Italy')


malta.reset_index().plot(x='year',y='energy_consumption_per_capita',kind ='bar',stacked=False,width=0.9)
plt.xlabel('year');plt.ylabel('Energy Consumption per capita');
plt.title('Energy Consumption per capita for Malta')
plt.show()

# %%
#print(sa)

# %whos DataFrame

# %%
#create dataframes for continents

africa = continents[(continents['ï»¿Entity'] == 'Africa')]

europe = continents[(continents['ï»¿Entity'] == 'Europe')]

north_america = continents[(continents['ï»¿Entity'] == 'North America')]

# %%
#print(africa,europe,north_america)

ax = central_africa.plot()

east_africa.plot(ax=ax)

# %%
#test = algeria.append([botswana, congo])

#test1 = test.append([czech, ghana])

#test2=test1.append([ireland,italy])

#country=test2.append([luxembourg,malta,mauritius,nigeria,norway,sa,seychelles,slovakia,switzerland,tunisia])

countrydf=afghanistan.append([algeria,angola,botswana,congo,czech,ghana,ireland,italy,luxembourg,malta,mauritius,nigeria,norway,sa,seychelles,slovakia,switzerland,tunisia])

# %%
print(countrydf)

# %%
countrydf.reset_index(drop=True, inplace=True)

# %%
countrydf[(['energy_consumption_per_capita'])][:10].plot(kind='bar')

# %%
countrydf.plot.line()
# sample1=df[df['code']=='NGA']
# x=pd.DataFrame([sample1.iloc[0].index,sample1.iloc[0].values]).T
# x.iloc[1:].plot()
# plt.show()

# %%
#afghanistan[(['energy_consumption_per_capita'])][:36].plot(kind='bar');

countrydf[(['energy_consumption_per_capita'])][:36].plot(kind='bar');

# %%
fig, ax = plt.subplots(figsize=(20, 5))
plt. title("Energy Consumption per capita for Afghanistan", fontsize=10)
plt. ylabel ("energy_consumption_per_capita", fontsize=10)
countrydf.groupby(["year","energy_consumption_per_capita"]).size().unstack("year").plot(kind="bar",ax=ax, fontsize=15)
plt. xlabel ("year", fontsize=10)
plt. show( )

# %%
angola.plot(x="year", y="energy_consumption_per_capita", kind="bar")

# %%
congo.plot(x="year", y="energy_consumption_per_capita", kind="bar")

# %%
afghanistan['ï»¿country'].value_counts()

# %%
print(afghanistan)

# %%
print(continents2)

# %%
continents2.plot(x="Year", y="Energy consumption per capita (kWh)", kind="bar")

# %%
del continents2['Code']

# %%
print(continents2)

# %%
#plotting with country details
fig, ax = plt.subplots(figsize=(15, 5))
plt.title("Afghanistan",fontsize=10)
plt.ylabel("Years",fontsize=10)
afghanistan.plot(kind="bar",ax=ax,fontsize=10)#groups by route and seat state(gender)
plt.xlabel("Energy",fontsize=10)
plt.show()

# %%
print(continents2)

# %%
#Graph plot of energy consumption by continent (Africa)
continents2.plot(x ='Year', y='Energy consumption per capita (kWh)', kind = 'line')
plt.show()

# %%
continents2.groupby(["Energy consumption per capita (kWh)","Year","ï»¿Entity"]).size().unstack("ï»¿Entity").idxmin()

# %%
continents2.groupby(["Energy consumption per capita (kWh)","ï»¿Entity","Year"]).size().unstack("Year").idxmax()

# %%
# column = continents2["Energy consumption per capita (kWh)"]
# max_value = column.max()


# print(max_value)

maxValues = continents2.max()
 
print(maxValues)

# %%
continents2[continents2['Energy consumption per capita (kWh)']==continents2['Energy consumption per capita (kWh)'].min()]

# %%
continents2[continents2['Energy consumption per capita (kWh)']==continents2['Energy consumption per capita (kWh)'].max()]

# %%
alldfs = [var
   for
   var in dir() if isinstance(eval(var), pd.core.frame.DataFrame)
]

print(alldfs)

# %%
print(afghanistan)

# %%
fig, ax = plt.subplots(figsize=(15, 5))
plt.title("Afghanistan Energy Consumption per capita (1980-2016)",fontsize=10)
plt.ylabel("Energy Consumption Per Capita",fontsize=10)
df2.plot(x='year', y='energy_consumption_per_capita',kind="bar",ax=ax,fontsize=10)
plt.xlabel("Years",fontsize=10)
plt.show()
